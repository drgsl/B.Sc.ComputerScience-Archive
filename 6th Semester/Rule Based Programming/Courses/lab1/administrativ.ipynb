# %% [markdown]
# https://sites.google.com/view/pbrfii/home?authuser=0
#
# https://sites.google.com/view/pbrfii/laboratoare?authuser=0
#
# https://sites.google.com/view/pbrfii/cursuri?authuser=0

# %% [markdown]
# 2lb de probramare
#
# putem veni la orice lab chiar si joi cand are master
#
# nu se poate prezenta pe mail
#
# un editor text - prolog - notepad++
#
# tema de sapt asta se poate prezenta si sapt viit nu doar sapt asta

# %% [markdown]
# motivul principal pt clipse = implementarea unor sisteme expert
#
# clipse ne lasa sa interpretar sisteme expert mai eficient
#
# veedeti niste astfel de sisteme
# urmarind demonstratoare dp link uri
# accesibile online
#
# alt exemplu de sistem expert:
# - troubleshoot er din orice (os)
# putine sunt referite ca fiind op expert
# - cele care ne lasa sa config ceva
# - suport client
# -
#
#
# ne facem o idee
# tema = interpretam un mini pt optionale
#
# ajutati un coleg din anu 2 pt asi alege cate un optional din fiecare pachet
#
# interactiunea este similara cu ce vedem in link uri
#
# in functie de raspunsuri continua cu alte intrebari
# intrb ulterioare depind de raspunsurile anterioare
# webmd (clipse)
# - va doare capu -> nu o sa intrebe de mana/picior
#
# raspunsul la intrb anterioare determina ce intrebari vor fi puse in continuare
#
#
#
# utilizatorul trb sa afle care sunt opt recomandate din fiecare pachet
#
# min 2intrb / pachet
# min 7intrb / total
#
# ce ai studiat/ce vrei sa faci dupa facultate/preferintele tale
#
#
# pt tema -> immplementam chestia asta in altcv (py, java, c)
# - sa vedem cum arata o interpretare neeficienta (multe if-uri)
# -- poate si if uri imbricate
#
# bonus:
# aceasi functionalitate si in clipse
# doar dupa ce facem implementarea in altcv decat in clipse
#
#
# altcv ce putem face la lab:
# - putem discuta la lab nelamuriri din curs
#
#
# - fara pcte de prezenta
# - puncte primim doar pe teme predate
#
#
#
#
# - pe pag cursurlui este un link la catalog (excel) - sa verif ca aparem in lista, altfel nu ne poate trece nota la finalul semestrului

# %% [markdown]
# ![image.png](attachment:image.png)
