# %% [markdown]
# programming paradigms:
# - imperative (easy to work with, fast execution, hard to adapt to changing goals)
# - declarative (based on goal, hard to debug & implement, slow execution
#                 BUT can solve almost anything u can describe)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
