# %% [markdown]
# 1)
#
#
#
# 2) det A = det (L * D * Lt) =detL * detD * detLt
# where Lt = L transpus
#
# la o matrice diagonala, detD = produsul elementelor de pe diagonala principala
# inmultim cele n elemente pt D
#
# ? determinatul unei matrice subdiagonala
#
# detXt = detX

# %% [markdown]
# 3)
#
# rezolvarea sistemelor de ecuatii
#
# 2x + 3y - z = 2
# 3x -  y + z = 5
# -x + y -z = 1
#
# ***
#
# 1.0 matricea sistemului
# A = (2 3 -1
#      3 -1 1
#      -1 1 -1)
# 2.1 x = deltaX / delta
# where delta = determinantul intregii matrici and delta != 0
# deltaX = determinantul matricii in care prima coloana este inlocuita cu vectorul termenilor liberi
#
# 2.2
# descompunem in forma chomlesky
# ax = b, where b = (2 5 1), vect termenilor liberi
# a e simetrica bcs aij = aji
#
# bcs its symetrical:
# LDLt * x = b
# if:
#  LD = u
# then:
# u*Lt * x = b
#
# (2 3 -1
#  3 -1 1
#  -1 1 -1) = (1 0 0
#               a 1 0
#               b c 1) * (m 0 0
#                         0 n 0
#                         0 0 p) * (1 a b
#                                   0 1 c
#                                   0 0 1)
#
#         = (m 0 0
#           ma, n 0
#           mb, cn, p) * (1 a b
#                         0 1 c
#                         0 0 1)
#
# ax = b
# LDLt * x = b
# u*Lt * x = b
#
# Lt = is supradiagonal actually, L = subdiagonal
#
# if y = Lt * x
# then u*y = b (I)
#
# (m 0 0
#  ma, n 0
#  mb, cn, p) * (alpha
#                beta
#                gamma) = (2
#                          5
#                          1)
# m*alpha + 0*beta + 0*gamma = 2 => alpha = 2/m
# ma*alpha + n*beta + 0*gamma = 5 => beta = (5 - ma*alpha)/n = (5 - ma*2/m)/n
# mb*alpha + cn*beta + p*gamma = 1 => gamma = (1 - mb*alpha - cn*beta)/p = (1 - mb*2/m - cn*(5 - ma*2/m)/n)/p
#
#
# we want to find x
#
# Lt * x = y (II) - second system that should be in the implementation
#
# (1 a b
#  0 1 c
#  0 0 1) * (alpha
#            beta
#            gamma) = (y1
#                      y2
#                      y3)
#
# gamma first, then beta, then alpha
# (landa)
#
# forbiden = functia numpy care face descompunerea chompsky
# numpy we can use for memorizing the matrices

# %% [markdown]
# 4)
# descompunere LU
#
# A = L U
#
# L - lower
# u - upper
#
# Ax = b
#
# *using numpy library here
# acelasi sistem si la ex3 si la ex4
# apelam functia din numpy cu matricea pe care am folosit o la ex3

# %% [markdown]
# 5) afisam norma?
# pasul de verificare a*x (aprox de tn) - b tinde spre 0
#
# || Ainit * xchal -b||2 -> 0 (normal euclidiana)
#
# xchal = solutia calculata cu chalsky
# Ainit = matricea initiala, a sistemului
# b = matricea termenilor liberi
#
# | (x1, x2 .. xn) - (b1, b2 .. bn) |2 = sqrt((x1 - b1)^2 + (x2 - b2)^2 + ... + (xn - bn)^2)
#
#
# D - tinem minte un singur vector, nu toate 0 urile
# L - nu:
# [1 0 0
#  2 1 0
#  3 2 0]
#  da:
#  [
# [ - ]
# [ 2]
# [3, 2]
#  ]

# %% [markdown]
# generam A-ul:
#
# generam diagonala cu 1
# generam subdiagonala
# facem simetria pe upper
#
# sau altfel da n am inteles cum
#
# D - toate elem pozitive

# %% [markdown]
# bonus:
#
# ft simplu
#
# 25pcte
#
# o matrice A
# o descompunem in L*D*Lt
#
# aij = mij - nu merge ca cv cu eroare
#
# |aij - mij| < epsilon (= 10^-5)

# %% [markdown]
# pag 7,8 avem implementarea
