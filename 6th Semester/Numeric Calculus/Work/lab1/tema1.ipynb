# %% [markdown]
# problem 1
#
#
# ![image.png](attachment:image.png)

# %%
for i in range(1, 1000):
    if(1+ 10 ** (-i) == 1):
        print(i)
        break
# Out:
# 16

# %%
p = 1e-1

while 1+p != 1:
    p = p/10    

print("smallest p that holds the doesnt hold the inequality:", p)
print(1+p)
print("1+p == 1 is:", 1+p == 1)
# print both?
# Out:
# smallest p that holds the doesnt hold the inequality: 1.0000000000000001e-16
# 1.0
# 1+p == 1 is: True

# %% [markdown]
# problem 2
#
# ![image.png](attachment:image.png)

# %%
u = 1e-15
x = 1.0

y = 0.1
z = u-y


print("pt adunare: ", end = "")
print((x+y) + z != x+ (y+z))
# nu mai este egalitate pt ca depaseste precizia masina


u = 1e-15
x = 1.0
y = 1 * u
z = 9 * u
print("pt inmultire: ", end = "")
print((x*y) * z != x* (y*z))

# answr:
# Out:
# pt adunare: True
# pt inmultire: False

# %% [markdown]
# problem 3
#
# ![image.png](attachment:image.png)
